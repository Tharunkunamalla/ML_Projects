# %%
import seaborn as sns
import matplotlib.pyplot as plt

tips = sns.load_dataset("tips")
sns.barplot(x="day", y="total_bill", data=tips)
plt.show()

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4]
y = [10, 20, 25, 30]

plt.plot(x, y)
plt.title("Simple Plot")
plt.show()

# %%
sns.lineplot(x=[1, 2, 3], y=[4, 5, 6])
plt.title("Mixed with Matplotlib")
plt.show()
