# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("canada_per_capita_income.csv")

# %%
print(data.head())
# Out:
#    year  per capita income (US$)
# 0  1970              3399.299037
# 1  1971              3768.297935
# 2  1972              4251.175484
# 3  1973              4804.463248
# 4  1974              5576.514583

# %%
print(data.tail())
# Out:
#     year  per capita income (US$)
# 42  2012              42665.25597
# 43  2013              42676.46837
# 44  2014              41039.89360
# 45  2015              35175.18898
# 46  2016              34229.19363

# %%
X = data[['year']]
Y = data[['per capita income (US$)']]

# %%
x_train, x_test, y_train, y_test = train_test_split(X,Y, test_size = 0.2, random_state = 42)

# %%
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
print(f"Slope(m) : ", model.coef_[0])
print(f"Intercept(c) : ", model.intercept_)
# Out:
# Slope(m) :  [815.14251301]
# Intercept(c) :  [-1605560.19879642]

# %%
y_predic = model.predict(x_test).flatten()   #actual and predicted are arrays with one element, so actual[0] extracts the scalar value.
y_actual = y_test.values.flatten()

for actual, predicted in zip(y_actual, y_predic):
    print(f"Actual: {actual:.2f} , Predicted: {predicted:.2f}")  #This way, the formatting :.2f works on scalars.
# Out:
# Actual: 17310.76 , Predicted: 22279.40
# Actual: 32755.18 , Predicted: 32061.11
# Actual: 16699.83 , Predicted: 21464.26
# Actual: 42676.47 , Predicted: 35321.68
# Actual: 15755.82 , Predicted: 19833.97
# Actual: 32738.26 , Predicted: 29615.68
# Actual: 9619.44 , Predicted: 10052.26
# Actual: 16426.73 , Predicted: 15758.26
# Actual: 5576.51 , Predicted: 3531.12
# Actual: 16369.32 , Predicted: 20649.11

# %%
# Plotting the regression line over the data
plt.scatter(X,Y, color='blue', label='Actual data')
plt.plot(X, model.predict(X), color='red', label='Regression line')
plt.xlabel('Year')
plt.ylabel('Percapita-Income')
plt.title('Year vs Percapita-Income')
plt.legend()
plt.grid(True)
plt.show()

# %%
from sklearn.metrics import mean_squared_error, r2_score

print("Mean Squared Error:", mean_squared_error(y_test, y_predic))
print("R-squared Score:", r2_score(y_test, y_predic))
# Out:
# Mean Squared Error: 15147815.5477862
# R-squared Score: 0.8751771396846304

# %%
Years = pd.DataFrame({'year': [2030]})  # Same column name as training
predicted_cost = model.predict(Years)

print("Predicted cost:", predicted_cost[0])
# Out:
# Predicted cost: [49179.10261174]

# %%
print(data.tail())
# Out:
#     year  per capita income (US$)
# 42  2012              42665.25597
# 43  2013              42676.46837
# 44  2014              41039.89360
# 45  2015              35175.18898
# 46  2016              34229.19363
