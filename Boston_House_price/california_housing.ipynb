# %%
from sklearn.datasets import fetch_california_housing

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score #cross validation data and trainin data gets divided in iterations
# %matplotlib inline

# %%
df = fetch_california_housing()

# %%
df
# Out:
# {'data': array([[   8.3252    ,   41.        ,    6.98412698, ...,    2.55555556,
#            37.88      , -122.23      ],
#         [   8.3014    ,   21.        ,    6.23813708, ...,    2.10984183,
#            37.86      , -122.22      ],
#         [   7.2574    ,   52.        ,    8.28813559, ...,    2.80225989,
#            37.85      , -122.24      ],
#         ...,
#         [   1.7       ,   17.        ,    5.20554273, ...,    2.3256351 ,
#            39.43      , -121.22      ],
#         [   1.8672    ,   18.        ,    5.32951289, ...,    2.12320917,
#            39.43      , -121.32      ],
#         [   2.3886    ,   16.        ,    5.25471698, ...,    2.61698113,
#            39.37      , -121.24      ]]),
#  'target': array([4.526, 3.585, 3.521, ..., 0.923, 0.847, 0.894]),
#  'frame': None,
#  'target_names': ['MedHouseVal'],
#  'feature_names': ['MedInc',
#   'HouseAge',
#   'AveRooms',
#   'AveBedrms',
#   'Population',
#   'AveOccup',
#   'Latitude',
# ...

# %%
pd.DataFrame(df.data)
# Out:
#             0     1         2         3       4         5      6       7
# 0      8.3252  41.0  6.984127  1.023810   322.0  2.555556  37.88 -122.23
# 1      8.3014  21.0  6.238137  0.971880  2401.0  2.109842  37.86 -122.22
# 2      7.2574  52.0  8.288136  1.073446   496.0  2.802260  37.85 -122.24
# 3      5.6431  52.0  5.817352  1.073059   558.0  2.547945  37.85 -122.25
# 4      3.8462  52.0  6.281853  1.081081   565.0  2.181467  37.85 -122.25
# ...       ...   ...       ...       ...     ...       ...    ...     ...
# 20635  1.5603  25.0  5.045455  1.133333   845.0  2.560606  39.48 -121.09
# 20636  2.5568  18.0  6.114035  1.315789   356.0  3.122807  39.49 -121.21
# 20637  1.7000  17.0  5.205543  1.120092  1007.0  2.325635  39.43 -121.22
# 20638  1.8672  18.0  5.329513  1.171920   741.0  2.123209  39.43 -121.32
# 20639  2.3886  16.0  5.254717  1.162264  1387.0  2.616981  39.37 -121.24
#
# [20640 rows x 8 columns]

# %%
dataset = pd.DataFrame(df.data)
dataset.columns = df.feature_names
print(dataset.head())
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25

# %%
dataset
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude
# 0        -122.23
# ...

# %%
dataset.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25

# %%
dataset['price'] = df.target

# %%
dataset
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  price
# ...

# %%
#Dividing the dataset into independent and dependent features

X = dataset.iloc[:,:-1]
Y = dataset.iloc[:,-1]

# %%
X.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25

# %%
from sklearn.model_selection import train_test_split


x_train, x_test,y_train, y_test = train_test_split(X,Y, test_size = 0.3, random_state = 42)

# %%
#Linear Regression
model = LinearRegression()
model.fit(x_train, y_train)
mse = cross_val_score(model, X, Y, scoring = 'neg_mean_squared_error', cv = 5)
print(mse)          #CV -- > cross validation done is 5 times in a loop
# Out:
# [-0.48485857 -0.62249739 -0.64621047 -0.5431996  -0.49468484]

# %%
mean_mse = np.mean(mse)
print(mean_mse)  #negative mean squared
# Out:
# -0.5582901717686536

# %%
#model.predict()

# %%
#Ridge Regression
from sklearn.linear_model import Ridge
from sklearn.model_selection import GridSearchCV
ridge = Ridge()

param = {'alpha' : [1e-15, 1e-10, 1e-8, 1e-3, 1e-2, 1, 5, 10, 20]}  # takes a alpha value which suits 
ridge_regressor = GridSearchCV(ridge, param,scoring = 'neg_mean_squared_error', cv =5)

ridge_regressor.fit(X,Y)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': [1e-15, 1e-10, 1e-08, 0.001, 0.01, 1, 5, 10,
#                                    20]},
#              scoring='neg_mean_squared_error')

# %%
print(ridge_regressor.best_params_)
print(ridge_regressor.best_score_)
# Out:
# {'alpha': 20}
# -0.5581020035625638

# %%
#if best score in ridge is -32 and  mean_mse in linear regression -37 then use linear bcz performing well

# %%
#Lasso Regression
from sklearn.linear_model import Lasso
from sklearn.model_selection import GridSearchCV
# Define model and parameters
lasso = Lasso()  # Increase max_iter to avoid convergence warnings
param = {'alpha': [1e-4, 1e-3, 1e-2, 1, 10, 20]}

# Grid search with 5-fold cross-validation
lasso_regressor = GridSearchCV(lasso, param, scoring='neg_mean_squared_error', cv=5)

# Fit model
lasso_regressor.fit(X, Y)
# Out:
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [0.0001, 0.001, 0.01, 1, 10, 20]},
#              scoring='neg_mean_squared_error')

# %%
print(lasso_regressor.best_params_)
print(lasso_regressor.best_score_)
# Out:
# {'alpha': 0.001}
# -0.5582759293868982

# %% [markdown]
# #After Adding traing and test

# %%
 #Linear Regression
model = LinearRegression()
mse = cross_val_score(model, x_train, y_train, scoring = 'neg_mean_squared_error', cv = 5)
print(mse)
# Out:
# [-0.54787556 -0.500835   -0.52045639 -0.51612252 -0.54883741]

# %%
mean_mse = np.mean(mse)
print(mean_mse)  #negative mean squared
# Out:
# -0.5268253746355749

# %%
#Ridge Regression
from sklearn.linear_model import Ridge
from sklearn.model_selection import GridSearchCV
ridge = Ridge()

param = {'alpha' : [1e-15, 1e-10, 1e-8, 1e-3, 1e-2, 1, 5, 10, 20]}  # takes a alpha value which suits 
ridge_regressor = GridSearchCV(ridge, param,scoring = 'neg_mean_squared_error', cv =5)

ridge_regressor.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': [1e-15, 1e-10, 1e-08, 0.001, 0.01, 1, 5, 10,
#                                    20]},
#              scoring='neg_mean_squared_error')

# %%
print(ridge_regressor.best_params_)
print(ridge_regressor.best_score_)
# Out:
# {'alpha': 1e-15}
# -0.5268253746355749

# %%
#Lasso
# Define model and parameters
lasso = Lasso()  # Increase max_iter to avoid convergence warnings
param = {'alpha': [1e-4, 1e-3, 1e-2, 1, 10, 20]}

# Grid search with 5-fold cross-validation
lasso_regressor = GridSearchCV(lasso, param, scoring='neg_mean_squared_error', cv=5)

# Fit model
lasso_regressor.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [0.0001, 0.001, 0.01, 1, 10, 20]},
#              scoring='neg_mean_squared_error')

# %%
print(lasso_regressor.best_params_)
print(lasso_regressor.best_score_)
# Out:
# {'alpha': 0.0001}
# -0.5268246054861063

# %% [markdown]
# #Precitions for algos

# %%
y_pred = lasso_regressor.predict(x_test)

from sklearn.metrics import r2_score

r2_score1 = r2_score(y_pred, y_test)

# %%
print(r2_score1)
# Out:
# 0.34487110615190575

# %%
y_pred = model.predict(x_test)

from sklearn.metrics import r2_score

r2_score1 = r2_score(y_pred, y_test)

# %%
print(r2_score1)
# Out:
# 0.34513393809439474
